# %%
import random
import numpy as np
import sys

nQueens=8
maxfit = 28
maxiter = 18000
mutation = 0.01
populationSize = 100

class QueensBoard():
    def __init__(self):
        self.sequence = None
        self.fitness = None
        self.survival = None
    def setSequence(self, val):
        self.sequence = val
    def setFitness(self, fitness):
        self.fitness = fitness
    def setSurvival(self, val):
        self.survival = val
    def getAttr(self):
        return {'sequence':sequence, 'fitness':fitness, 'survival':survival}
    
def fitness(queenpos = None):

    clashes = 0;
    row_col_clashes = abs(len(queenpos) - len(np.unique(queenpos)))
    clashes += row_col_clashes

    for i in range(len(queenpos)):
        for j in range(len(queenpos)):
            if ( i != j):
                dx = abs(i-j)
                dy = abs(queenpos[i] - queenpos[j])
                if(dx == dy):
                    clashes += 1
    return 28 - clashes


def generatequeenpos():

    global nQueens
    queenpos = np.arange(nQueens)
    np.random.shuffle(queenpos)
    return queenpos

def generatePopulation(population_size = 100):
  

    population = [QueensBoard() for i in range(population_size)]
    for i in range(population_size):
        population[i].setSequence(generatequeenpos())
        population[i].setFitness(fitness(population[i].sequence))

    return population
def gensurvival():
    summation_fitness = np.sum([x.fitness for x in poplist])
    
    for each in poplist:
        each.survival = each.fitness/summation_fitness
    
def getParent():
    globals()
    parent1, parent2 = None, None

    

    while True:
        parent1_random = np.random.rand()
        
        parent1_rn = [x for x in poplist if x.survival <= parent1_random]
        try:
            th = np.random.randint(len(parent1_rn), size=1)
            t=th[0]
            parent1 = parent1_rn[t]
            break
        except:
            pass

    while True:
        parent2_random = np.random.rand()
        parent2_rn = [x for x in poplist if x.survival <= parent2_random]
        
        try:
            th = np.random.randint(len(parent2_rn), size=1)
            t=th[0]
            parent2 = parent2_rn[t]
            if parent2 != parent1:
                break
            else:
                #print ("equal parents")
                continue
        except:
            print ("exception")
            continue

    if parent1 is not None and parent2 is not None:
        
        return parent1, parent2
    else:
        sys.exit(-1)

def reproduce_crossover(parent1, parent2):
    globals()
    n = len(parent1.sequence)
    ch = np.random.randint(n, size=1)
    c=ch[0]
    
    child = QueensBoard()
    child.sequence = []
    child.sequence.extend(parent1.sequence[:c])
    child.sequence.extend(parent2.sequence[c:])
    child.setFitness(fitness(child.sequence))
    summation_fitness = np.sum([x.fitness for x in poplist])
    child.survival = child.fitness/summation_fitness
    
    return child

def mutate(child):
    
    if child.survival < mutation:
        
        ch = np.random.randint(8, size=1)
        c=ch[0]
        child.sequence[c] = np.random.randint(8)
        
    return child


def geneticiteration(iteration):
    print (" #"*10 ,"Executing Genetic  generation : ", iteration , " #"*10)
    globals()
    newpopulation = []
    for i in range(len(poplist)):
        parent1, parent2 = getParent()
        
        child = reproduce_crossover(parent1, parent2)
        child = mutate(child)
        newpopulation.append(child)
    return newpopulation

def stop():
    globals()
    survivalval=[pos.survival for pos in poplist]
    fitnessvals = [pos.fitness for pos in poplist]
    
    if maxfit in fitnessvals:
        return True
    if maxiter == iteration:
        return True
    return False


poplist=generatePopulation(populationSize)

gensurvival()


iteration = 0
while not stop():
    poplist = geneticiteration(iteration)
    iteration +=1 
    

print ("Iteration number : ", iteration)
for each in poplist:
    if each.fitness == 28:
        print (each.sequence)
# Out:
#  # # # # # # # # # # Executing Genetic  generation :  0  # # # # # # # # # #
#  # # # # # # # # # # Executing Genetic  generation :  1  # # # # # # # # # #
#  # # # # # # # # # # Executing Genetic  generation :  2  # # # # # # # # # #
#  # # # # # # # # # # Executing Genetic  generation :  3  # # # # # # # # # #
# exception
#  # # # # # # # # # # Executing Genetic  generation :  4  # # # # # # # # # #
#  # # # # # # # # # # Executing Genetic  generation :  5  # # # # # # # # # #
#  # # # # # # # # # # Executing Genetic  generation :  6  # # # # # # # # # #
#  # # # # # # # # # # Executing Genetic  generation :  7  # # # # # # # # # #
#  # # # # # # # # # # Executing Genetic  generation :  8  # # # # # # # # # #
# exception
#  # # # # # # # # # # Executing Genetic  generation :  9  # # # # # # # # # #
# exception
#  # # # # # # # # # # Executing Genetic  generation :  10  # # # # # # # # # #
# exception
#  # # # # # # # # # # Executing Genetic  generation :  11  # # # # # # # # # #
# ...

# %%
# Out:
# [3 4 1 2 5 7 0 6]
# [3 4 1]
